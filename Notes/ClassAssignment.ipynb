# %%
import pandas as pd

# %%
df = pd.read_csv('national-activity-indicators.csv')

# %%
df
# Out:
#       Week  % of Specimens Positive for SARS-CoV-2  \
# 0   202010                                    11.8
# 1   202011                                     9.5
# 2   202012                                     9.0
# 3   202013                                    13.1
# 4   202014                                    22.1
# 5   202015                                    21.7
# 6   202016                                    19.0
# 7   202017                                    15.7
# 8   202018                                    12.8
# 9   202019                                    10.0
# 10  202020                                     7.8
# 11  202021                                     6.9
# 12  202022                                     6.5
# 13  202023                                     6.2
# 14  202024                                     6.6
# 15  202025                                     8.3
# 16  202026                                     9.5
# ...

# %%
df.shape
# Out:
# (46, 6)

# %%
df.dtypes
# Out:
# Week                                                                           int64
# % of Specimens Positive for SARS-CoV-2                                       float64
# % of Visits for CLI (NSSP)                                                   float64
# % of Visits for ILI (ILINet)                                                 float64
# Laboratory-Confirmed COVID-19-associated hospitalization rate per 100,000    float64
# % of Deaths due to Pneumonia, Influenza or COVID                             float64
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=46, step=1)

# %% [markdown]
# ## Which week had the highest % of Specimens Positive for SARS-CoV-2

# %%
df.iloc[[df['% of Specimens Positive for SARS-CoV-2'].idxmax()]]['Week']
# Out:
# 4    202014
# Name: Week, dtype: int64

# %% [markdown]
# ## Week with highest Ratio of Percentage of Covid cases to Percentage of Death

# %%
df['% positive covid cased to % of deaths'] = df['% of Specimens Positive for SARS-CoV-2'] / df['% of Deaths due to Pneumonia, Influenza or COVID']
df[df['% positive covid cased to % of deaths'].max() == df['% positive covid cased to % of deaths']]
# Out:
#      Week  % of Specimens Positive for SARS-CoV-2  % of Visits for CLI (NSSP)  \
# 0  202010                                    11.8                         2.2
#
#    % of Visits for ILI (ILINet)  \
# 0                           5.3
#
#    Laboratory-Confirmed COVID-19-associated hospitalization rate per 100,000  \
# 0                                                0.1
#
#    % of Deaths due to Pneumonia, Influenza or COVID  \
# 0                                               7.8
#
#    % positive covid cased to % of deaths
# 0                               1.512821
