# %%
import pandas as pd
import numpy as np

# %%
sal = pd.read_csv('salaries.csv')
# Out:
# C:\Users\Gary\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3,4,5,6,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
sal.describe()
# Out:
#                   Id       TotalPay  TotalPayBenefits           Year  Notes
# count  148654.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    74327.500000   74768.321972      93692.554811    2012.522643    NaN
# std     42912.857795   50517.005274      62793.533483       1.117538    NaN
# min         1.000000    -618.130000       -618.130000    2011.000000    NaN
# 25%     37164.250000   36168.995000      44065.650000    2012.000000    NaN
# 50%     74327.500000   71426.610000      92404.090000    2013.000000    NaN
# 75%    111490.750000  105839.135000     132876.450000    2014.000000    NaN
# max    148654.000000  567595.430000     567595.430000    2014.000000    NaN

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
# string is an object
sal.dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay              object
# OvertimePay          object
# OtherPay             object
# Benefits             object
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status               object
# dtype: object

# %%
sal['BasePay']
# Out:
# 0            167411.18
# 1            155966.02
# 2            212739.13
# 3              77916.0
# 4             134401.6
#               ...
# 148649            0.00
# 148650    Not Provided
# 148651    Not Provided
# 148652    Not Provided
# 148653            0.00
# Name: BasePay, Length: 148654, dtype: object

# %%
# Change what columns to change to floats (BasePay, OvertimePay, OtherPay, Benefits)

# %%
# List columns
sal.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
# changing to numeric type from object to float
sal[['BasePay', 'OvertimePay', 'OtherPay','Benefits']] = sal[['BasePay', 'OvertimePay', 'OtherPay','Benefits']].apply(pd.to_numeric, errors='coerce')

# %%
# NaN = null
sal['BasePay']
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
#             ...
# 148649         0.00
# 148650          NaN
# 148651          NaN
# 148652          NaN
# 148653         0.00
# Name: BasePay, Length: 148654, dtype: float64

# %%
sal['BasePay'].min()
# Out:
# -166.01

# %%
sal.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448841    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
list(sal['JobTitle'])
# Out:
# ['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#  'CAPTAIN III (POLICE DEPARTMENT)',
#  'CAPTAIN III (POLICE DEPARTMENT)',
#  'WIRE ROPE CABLE MAINTENANCE MECHANIC',
#  'DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)',
#  'ASSISTANT DEPUTY CHIEF II',
#  'BATTALION CHIEF, (FIRE DEPARTMENT)',
#  'DEPUTY DIRECTOR OF INVESTMENTS',
#  'BATTALION CHIEF, (FIRE DEPARTMENT)',
#  'CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',
#  'ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',
#  'CAPTAIN III (POLICE DEPARTMENT)',
#  'EXECUTIVE CONTRACT EMPLOYEE',
#  'DEPARTMENT HEAD V',
#  'BATTALION CHIEF, (FIRE DEPARTMENT)',
#  'COMMANDER III, (POLICE DEPARTMENT)',
#  'DEPARTMENT HEAD V',
#  'CAPTAIN, EMERGENCYCY MEDICAL SERVICES',
#  'BATTALION CHIEF, (FIRE DEPARTMENT)',
#  'ASSISTANT MEDICAL EXAMINER',
#  'ASSISTANT MEDICAL EXAMINER',
#  'ASSISTANT MEDICAL EXAMINER',
#  'CAPTAIN, FIRE SUPPRESSION',
#  'BATTALION CHIEF, (FIRE DEPARTMENT)',
#  'CAPTAIN, FIRE SUPPRESSION',
#  'CHIEF OF POLICE',
# ...

# %%
# Return the unique values, not dupes
list(sal['JobTitle'].unique())
# Out:
# ['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#  'CAPTAIN III (POLICE DEPARTMENT)',
#  'WIRE ROPE CABLE MAINTENANCE MECHANIC',
#  'DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)',
#  'ASSISTANT DEPUTY CHIEF II',
#  'BATTALION CHIEF, (FIRE DEPARTMENT)',
#  'DEPUTY DIRECTOR OF INVESTMENTS',
#  'CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',
#  'ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',
#  'EXECUTIVE CONTRACT EMPLOYEE',
#  'DEPARTMENT HEAD V',
#  'COMMANDER III, (POLICE DEPARTMENT)',
#  'CAPTAIN, EMERGENCYCY MEDICAL SERVICES',
#  'ASSISTANT MEDICAL EXAMINER',
#  'CAPTAIN, FIRE SUPPRESSION',
#  'CHIEF OF POLICE',
#  'DEPUTY CHIEF III (POLICE DEPARTMENT)',
#  'INSPECTOR III, (POLICE DEPARTMENT)',
#  'ELECTRONIC MAINTENANCE TECHNICIAN',
#  'ADMINISTRATOR, SFGH MEDICAL CENTER',
#  'LIEUTENANT III (POLICE DEPARTMENT)',
#  'FIREFIGHTER',
#  'NURSING SUPERVISOR PSYCHIATRIC',
#  'MAYOR',
#  'LIEUTENANT, FIRE DEPARTMENT',
#  'INCIDENT SUPPORT SPECIALIST',
#  'ANESTHETIST',
# ...

# %%
len(list(sal['JobTitle'].unique()))
# Out:
# 2159

# %%
# nunique is the length of unique values
sal['JobTitle'].nunique()
# Out:
# 2159

# %%
# dataframe groupby object
sal.groupby('JobTitle')

# %%
# now its a Series
sal.groupby('JobTitle')['BasePay']

# %%
# Maximum of each job title
sal.groupby('JobTitle')['BasePay'].max()
# Out:
# JobTitle
# ACCOUNT CLERK                                     60838.20
# ACCOUNTANT                                        65392.01
# ACCOUNTANT INTERN                                 58501.72
# ACPO,JuvP, Juv Prob (SFERS)                       62290.78
# ACUPUNCTURIST                                     66374.40
#                                                     ...
# X-RAY LABORATORY AIDE                             60086.62
# X-Ray Laboratory Aide                             66123.01
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.91
# Youth Comm Advisor                                57544.73
# ZOO CURATOR                                       43148.00
# Name: BasePay, Length: 2159, dtype: float64

# %%
# min
sal.groupby('JobTitle')['BasePay'].min()
# Out:
# JobTitle
# ACCOUNT CLERK                                       614.00
# ACCOUNTANT                                            0.00
# ACCOUNTANT INTERN                                  2981.53
# ACPO,JuvP, Juv Prob (SFERS)                       62290.78
# ACUPUNCTURIST                                     66374.40
#                                                     ...
# X-RAY LABORATORY AIDE                              4690.68
# X-Ray Laboratory Aide                              1007.00
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.91
# Youth Comm Advisor                                13915.80
# ZOO CURATOR                                       43148.00
# Name: BasePay, Length: 2159, dtype: float64

# %%
# count
sal.groupby('JobTitle')['BasePay'].count()
# Out:
# JobTitle
# ACCOUNT CLERK                                      83
# ACCOUNTANT                                          5
# ACCOUNTANT INTERN                                  48
# ACPO,JuvP, Juv Prob (SFERS)                         1
# ACUPUNCTURIST                                       1
#                                                  ...
# X-RAY LABORATORY AIDE                              26
# X-Ray Laboratory Aide                             100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS      1
# Youth Comm Advisor                                  4
# ZOO CURATOR                                         1
# Name: BasePay, Length: 2159, dtype: int64

# %%
sal.groupby('JobTitle')['Id'].count()
# Out:
# JobTitle
# ACCOUNT CLERK                                      83
# ACCOUNTANT                                          5
# ACCOUNTANT INTERN                                  48
# ACPO,JuvP, Juv Prob (SFERS)                         1
# ACUPUNCTURIST                                       1
#                                                  ...
# X-RAY LABORATORY AIDE                              26
# X-Ray Laboratory Aide                             100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS      1
# Youth Comm Advisor                                  4
# ZOO CURATOR                                         1
# Name: Id, Length: 2159, dtype: int64

# %%
type(sal.groupby('JobTitle')['Id'].count())
# Out:
# pandas.core.series.Series

# %%
# average benefits for each job title
sal.groupby('JobTitle')['Benefits'].mean()
# Out:
# JobTitle
# ACCOUNT CLERK                                            NaN
# ACCOUNTANT                                               NaN
# ACCOUNTANT INTERN                                        NaN
# ACPO,JuvP, Juv Prob (SFERS)                       17975.5900
# ACUPUNCTURIST                                            NaN
#                                                      ...
# X-RAY LABORATORY AIDE                                    NaN
# X-Ray Laboratory Aide                             18697.1805
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS           NaN
# Youth Comm Advisor                                18704.2425
# ZOO CURATOR                                              NaN
# Name: Benefits, Length: 2159, dtype: float64

# %%
# What is the difference between highest max basepay and lowest max basepay

# %%
maxsal = sal.groupby('JobTitle')['BasePay'].max()

# %%
maxsal.max() - maxsal.min()
# Out:
# 319275.01

# %%
maxsal.max()
# Out:
# 319275.01

# %%
maxsal.min()
# Out:
# 0.0

# %%
maxsal[maxsal <= 0]
# Out:
# JobTitle
# ASSISTANT RECREATION SUPERVISOR            0.0
# Assistant Recreation Director              0.0
# Cashier 3                                  0.0
# Conversion                                 0.0
# PUBLIC SAFETY COMMUNICATIONS TECHNICIAN    0.0
# RECREATION DIRECTOR                        0.0
# Recreation Director                        0.0
# WAREHOUSE WORKER                           0.0
# Name: BasePay, dtype: float64

# %%
sal[sal['JobTitle'] == 'RECREATION DIRECTOR']
# Out:
#           Id       EmployeeName             JobTitle  BasePay  OvertimePay  \
# 30913  30914        HUEY THOMAS  RECREATION DIRECTOR      0.0       225.98
# 32097  32098        SCOTT GOLDE  RECREATION DIRECTOR      0.0         0.00
# 32545  32546   MICHAEL CHEATHAM  RECREATION DIRECTOR      0.0        67.55
# 33565  33566    KEITH BURROUGHS  RECREATION DIRECTOR      0.0         0.00
# 34909  34910      DAVETTE MINOR  RECREATION DIRECTOR      0.0         0.00
# 34910  34911        JAMES BROWN  RECREATION DIRECTOR      0.0         0.00
# 34946  34947       JERI JACKSON  RECREATION DIRECTOR      0.0         0.00
# 35059  35060  GWENDOLYN WIGGINS  RECREATION DIRECTOR      0.0         0.00
# 35179  35180        EDWARD WONG  RECREATION DIRECTOR      0.0         0.00
# 35291  35292     JANELLE PIERCE  RECREATION DIRECTOR      0.0         0.00
#
#        OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 30913  12315.65       NaN  12541.63          12541.63  2011    NaN
# ...

# %%
my_ones = np.ones(50)
len(my_ones)
# Out:
# 50

# %%
#stats=np.array([ 1,  4,  7, 10, 13, 16, 19])

# %%
#stats[0:2]
# Out:
# array([1, 4])

# %%
stats = np.array([[ 1,  5,  9, 13],
       [17, 21, 25, 29],
       [33, 37, 41, 45]])

# %%
print(stats[1:,:2])
# Out:
# [[17 21]
#  [33 37]]

# %%
# 1. Create a numpy array that has 25 random numbers ranging between 1 and 100.
arr = np.random.randint(low=1, high=100, size=25)
# 2. Print out the array.
print(arr)
# 3. Print out the average of all the numbers in the array.
print(np.average(arr))
# 4. Print out the median of all the numbers in the array.
print(np.median(arr))
# 5. If the median and average are within 3 of each other, print out all numbers of the array that are greater than 25, otherwise print out all numbers that are > 50
avg = np.average(arr)
med = np.median(arr)
med - avg
if (med-avg) <= 3:
    print(arr[arr>25])
else:
    print(arr[arr>50])

# %%
arr = np.random.randint(low=1, high=100, size=25)

# %%
print(arr)
# Out:
# [61 64 59 39 97 19 99 66 33 64 88 59 53  2 13 25 11 87 15 91 73 98 51 98
#  56]

# %%
print(np.average(arr))
# Out:
# 56.84

# %%
print(np.median(arr))
# Out:
# 59.0

# %%
avg = np.average(arr)
med = np.median(arr)
med - avg
if (med-avg) <= 3:
    print(arr[arr>25])
else:
    print(arr[arr>50])
# Out:
# [61 64 59 39 97 99 66 33 64 88 59 53 87 91 73 98 51 98 56]
