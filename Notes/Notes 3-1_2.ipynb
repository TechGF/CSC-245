# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Street_Pothole_Work_Orders_-_Closed__Dataset_.csv')

# %%
df.head()
# Out:
#                                             the_geom        DefNum InitBy  \
# 0  MULTILINESTRING ((-73.94380842208841 40.584992...  DB2004287021    CSC
# 1  MULTILINESTRING ((-73.98570910180825 40.641185...  DB2006085009    CSC
# 2  MULTILINESTRING ((-73.934872108524 40.67959308...  DB2007166005    CSC
# 3  MULTILINESTRING ((-73.9779394087253 40.6898061...  DB2009352004    CSC
# 4  MULTILINESTRING ((-73.97501506812608 40.640761...  DB2009362038    CSC
#
#   HouseNum                 OFT   OnFaceName       OnPrimName     FrmPrimNam  \
# 0      NaN  318630377030377030   BEDFORD AV   BEDFORD AVENUE   BELT PARKWAY
# 1      NaN  306380308480308530        13 AV        13 AVENUE      38 STREET
# 2     1688  342730355530375430    FULTON ST    FULTON STREET   LEWIS AVENUE
# 3       45  380030331530342730  ST FELIX ST  ST FELIX STREET  DEKALB AVENUE
# 4      514  313830335030367730         AV C         AVENUE C  EAST 5 STREET
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 323871 entries, 0 to 323870
# Data columns (total 15 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   the_geom    323871 non-null  object
#  1   DefNum      323871 non-null  object
#  2   InitBy      323871 non-null  object
#  3   HouseNum    219613 non-null  object
#  4   OFT         323871 non-null  int64
#  5   OnFaceName  323040 non-null  object
#  6   OnPrimName  323794 non-null  object
#  7   FrmPrimNam  323841 non-null  object
#  8   ToPrimName  323765 non-null  object
#  9   SpecLoc     108833 non-null  object
#  10  Boro        323871 non-null  object
#  11  Source      323871 non-null  object
#  12  RptDate     323871 non-null  object
#  13  RptClosed   323871 non-null  object
#  14  Shape_Leng  323871 non-null  float64
# dtypes: float64(1), int64(1), object(13)
# memory usage: 37.1+ MB

# %%
# check number of null values in df
df.isna().sum().sum()
# Out:
# 320340

# %%
# check with columns have null values return boolean
df.isna().any()
# Out:
# the_geom      False
# DefNum        False
# InitBy        False
# HouseNum       True
# OFT           False
# OnFaceName     True
# OnPrimName     True
# FrmPrimNam     True
# ToPrimName     True
# SpecLoc        True
# Boro          False
# Source        False
# RptDate       False
# RptClosed     False
# Shape_Leng    False
# dtype: bool

# %%
# check numbers of null values in each columns
df.isna().sum()
# Out:
# the_geom           0
# DefNum             0
# InitBy             0
# HouseNum      104258
# OFT                0
# OnFaceName       831
# OnPrimName        77
# FrmPrimNam        30
# ToPrimName       106
# SpecLoc       215038
# Boro               0
# Source             0
# RptDate            0
# RptClosed          0
# Shape_Leng         0
# dtype: int64

# %%
# Convert RptDate from object to new type (datetime)
df['Report Date'] = pd.to_datetime(df['RptDate'])

# %%
# return the date = 2021-10-01 and Boro = staten island
df[(df['Report Date'] >= '2021-10-01') & (df['Boro'] == 'S')]
# Out:
#                                                  the_geom        DefNum  \
# 279049  MULTILINESTRING ((-74.10582614294682 40.600781...  DS2021274002
# 279050  MULTILINESTRING ((-74.09868319847438 40.619202...  DS2021274004
# 279051  MULTILINESTRING ((-74.10090957402407 40.591021...  DS2021274006
# 279052  MULTILINESTRING ((-74.09640364625918 40.622334...  DS2021275003
# 279053  MULTILINESTRING ((-74.16265183458643 40.630230...  DS2021276004
# ...                                                   ...           ...
# 279587  MULTILINESTRING ((-74.1882648310706 40.5532753...  DS2022028038
# 279588  MULTILINESTRING ((-74.18609308340261 40.554548...  DS2022028039
# 279589  MULTILINESTRING ((-74.18614424302007 40.551973...  DS2022028040
# 279590  MULTILINESTRING ((-74.18148062132548 40.523654...  DS2022028042
# 279591  MULTILINESTRING ((-74.18043123012754 40.524047...  DS2022028043
#
#        InitBy HouseNum                 OFT       OnFaceName  \
# ...

# %%
df[(df['Report Date'] >= '2021-10-01')].groupby('Boro').count()
# Out:
#       the_geom  DefNum  InitBy  HouseNum   OFT  OnFaceName  OnPrimName  \
# Boro
# B         1793    1793    1793      1057  1793        1793        1793
# M          595     595     595       411   595         595         595
# Q         2238    2238    2238      1491  2238        2232        2238
# S          543     543     543       322   543         542         543
# X          851     851     851       646   851         849         851
#
#       FrmPrimNam  ToPrimName  SpecLoc  Source  RptDate  RptClosed  Shape_Leng  \
# Boro
# B           1793        1793      172    1793     1793       1793        1793
# M            595         595       54     595      595        595         595
# Q           2238        2238      406    2238     2238       2238        2238
# S            543         543      168     543      543        543         543
# X            851         851      118     851      851        851         851
#
#       Report Date
# Boro
# B            1793
# ...
