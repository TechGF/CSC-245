# %%
import numpy as np
import pandas as pd

# %%
salaries = pd.read_csv("Salaries.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3,4,5,6,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
salaries.dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay              object
# OvertimePay          object
# OtherPay             object
# Benefits             object
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status               object
# dtype: object

# %%
salaries
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
salaries['BasePay']
# Out:
# 0            167411.18
# 1            155966.02
# 2            212739.13
# 3              77916.0
# 4             134401.6
#               ...
# 148649            0.00
# 148650    Not Provided
# 148651    Not Provided
# 148652    Not Provided
# 148653            0.00
# Name: BasePay, Length: 148654, dtype: object

# %%
salaries.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
salaries[['BasePay', 'OvertimePay', 'OtherPay',
          'Benefits']] = 
salaries[['BasePay', 'OvertimePay','OtherPay'
          ,'Benefits']].apply(pd.to_numeric, errors='coerce')

# %%
salaries.dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status               object
# dtype: object

# %%
salaries['BasePay']
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
#             ...
# 148649         0.00
# 148650          NaN
# 148651          NaN
# 148652          NaN
# 148653         0.00
# Name: BasePay, Length: 148654, dtype: float64

# %%
salaries.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# ...

# %%
salaries['BasePay'].min()
# Out:
# -166.01

# %%
salaries.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448841    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
list(salaries['JobTitle'])
# Out:
# ['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#  'CAPTAIN III (POLICE DEPARTMENT)',
#  'CAPTAIN III (POLICE DEPARTMENT)',
#  'WIRE ROPE CABLE MAINTENANCE MECHANIC',
#  'DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)',
#  'ASSISTANT DEPUTY CHIEF II',
#  'BATTALION CHIEF, (FIRE DEPARTMENT)',
#  'DEPUTY DIRECTOR OF INVESTMENTS',
#  'BATTALION CHIEF, (FIRE DEPARTMENT)',
#  'CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',
#  'ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',
#  'CAPTAIN III (POLICE DEPARTMENT)',
#  'EXECUTIVE CONTRACT EMPLOYEE',
#  'DEPARTMENT HEAD V',
#  'BATTALION CHIEF, (FIRE DEPARTMENT)',
#  'COMMANDER III, (POLICE DEPARTMENT)',
#  'DEPARTMENT HEAD V',
#  'CAPTAIN, EMERGENCYCY MEDICAL SERVICES',
#  'BATTALION CHIEF, (FIRE DEPARTMENT)',
#  'ASSISTANT MEDICAL EXAMINER',
#  'ASSISTANT MEDICAL EXAMINER',
#  'ASSISTANT MEDICAL EXAMINER',
#  'CAPTAIN, FIRE SUPPRESSION',
#  'BATTALION CHIEF, (FIRE DEPARTMENT)',
#  'CAPTAIN, FIRE SUPPRESSION',
#  'CHIEF OF POLICE',
# ...

# %%
len(list(salaries['JobTitle'].unique()))
# Out:
# 2159

# %%
salaries['JobTitle'].nunique()
# Out:
# 2159

# %%
salaries.groupby('JobTitle')['Id'].count()
# Out:
# JobTitle
# ACCOUNT CLERK                                      83
# ACCOUNTANT                                          5
# ACCOUNTANT INTERN                                  48
# ACPO,JuvP, Juv Prob (SFERS)                         1
# ACUPUNCTURIST                                       1
#                                                  ...
# X-RAY LABORATORY AIDE                              26
# X-Ray Laboratory Aide                             100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS      1
# Youth Comm Advisor                                  4
# ZOO CURATOR                                         1
# Name: Id, Length: 2159, dtype: int64

# %%
#average benefits for each job title
salaries.groupby('JobTitle')
salaries['Benefits'].mean()
# Out:
# JobTitle
# ACCOUNT CLERK                                            NaN
# ACCOUNTANT                                               NaN
# ACCOUNTANT INTERN                                        NaN
# ACPO,JuvP, Juv Prob (SFERS)                       17975.5900
# ACUPUNCTURIST                                            NaN
#                                                      ...
# X-RAY LABORATORY AIDE                                    NaN
# X-Ray Laboratory Aide                             18697.1805
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS           NaN
# Youth Comm Advisor                                18704.2425
# ZOO CURATOR                                              NaN
# Name: Benefits, Length: 2159, dtype: float64

# %%
#what is the difference between 
#highest max base pay and lowest max base pay

# %%
salaries[salaries['JobTitle'] == 'ACCOUNT CLERK']
# Out:
#           Id      EmployeeName       JobTitle   BasePay  OvertimePay  \
# 20765  20766    NAPOLEON VIRAY  ACCOUNT CLERK  60838.20         0.00
# 20867  20868  BERNADETTE RAMOS  ACCOUNT CLERK  49777.81     10753.06
# 21638  21639       SUSAN CHANG  ACCOUNT CLERK  51306.28      5406.34
# 22972  22973  OLIVIA BOUDREAUX  ACCOUNT CLERK  49778.15      3811.68
# 24132  24133        LI-XIN CAI  ACCOUNT CLERK  49777.80      1390.45
# ...      ...               ...            ...       ...          ...
# 31245  31246     ALISHA WILLIS  ACCOUNT CLERK  11247.02         0.00
# 32035  32036    BARBARA BLOUNT  ACCOUNT CLERK   8681.58        69.82
# 34974  34975          LIEN LUM  ACCOUNT CLERK   1630.00         0.00
# 34975  34976        RACHEL LAU  ACCOUNT CLERK   1630.00         0.00
# 35637  35638     TSE SHIH LENG  ACCOUNT CLERK    614.00         0.00
#
#        OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 20765      0.00       NaN  60838.20          60838.20  2011    NaN
# ...

# %%
maxsalaries = salaries.groupby('JobTitle')['BasePay'].max()

# %%
maxsalaries.max() - maxsalaries.min()
# Out:
# 319275.01

# %%
maxsalaries.max()
# Out:
# 319275.01

# %%
 maxsalaries.min()
# Out:
# 0.0

# %%
maxsalaries
# Out:
# JobTitle
# ACCOUNT CLERK                                     60838.20
# ACCOUNTANT                                        65392.01
# ACCOUNTANT INTERN                                 58501.72
# ACPO,JuvP, Juv Prob (SFERS)                       62290.78
# ACUPUNCTURIST                                     66374.40
#                                                     ...
# X-RAY LABORATORY AIDE                             60086.62
# X-Ray Laboratory Aide                             66123.01
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.91
# Youth Comm Advisor                                57544.73
# ZOO CURATOR                                       43148.00
# Name: BasePay, Length: 2159, dtype: float64

# %%
maxsalaries[maxsalaries <= 0]
# Out:
# JobTitle
# ASSISTANT RECREATION SUPERVISOR            0.0
# Assistant Recreation Director              0.0
# Cashier 3                                  0.0
# Conversion                                 0.0
# PUBLIC SAFETY COMMUNICATIONS TECHNICIAN    0.0
# RECREATION DIRECTOR                        0.0
# Recreation Director                        0.0
# WAREHOUSE WORKER                           0.0
# Name: BasePay, dtype: float64

# %%
salaries[salaries['JobTitle'] == 'RECREATION DIRECTOR']
# Out:
#           Id       EmployeeName             JobTitle  BasePay  OvertimePay  \
# 30913  30914        HUEY THOMAS  RECREATION DIRECTOR      0.0       225.98
# 32097  32098        SCOTT GOLDE  RECREATION DIRECTOR      0.0         0.00
# 32545  32546   MICHAEL CHEATHAM  RECREATION DIRECTOR      0.0        67.55
# 33565  33566    KEITH BURROUGHS  RECREATION DIRECTOR      0.0         0.00
# 34909  34910      DAVETTE MINOR  RECREATION DIRECTOR      0.0         0.00
# 34910  34911        JAMES BROWN  RECREATION DIRECTOR      0.0         0.00
# 34946  34947       JERI JACKSON  RECREATION DIRECTOR      0.0         0.00
# 35059  35060  GWENDOLYN WIGGINS  RECREATION DIRECTOR      0.0         0.00
# 35179  35180        EDWARD WONG  RECREATION DIRECTOR      0.0         0.00
# 35291  35292     JANELLE PIERCE  RECREATION DIRECTOR      0.0         0.00
#
#        OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 30913  12315.65       NaN  12541.63          12541.63  2011    NaN
# ...

# %%
def myfun(s):
    return s/2

# %%
salaries['BasePay'].apply(myfun)
# Out:
# 0          83705.590
# 1          77983.010
# 2         106369.565
# 3          38958.000
# 4          67200.800
#              ...
# 148649         0.000
# 148650           NaN
# 148651           NaN
# 148652           NaN
# 148653         0.000
# Name: BasePay, Length: 148654, dtype: float64
